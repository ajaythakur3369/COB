# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaythakur3369/COB/blob/main/Task_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project - Task-02**
# ## **Developed By - Ajay Thakur (ajaythakur3369@gmail.com)**
# ## **Branch Name - Electronics and Communication Engineering**
# ## **Institute Name - Indian Institute of Information Technology Kota (An Institute of National Importance under an Act of Parliament)**
# ## **Submitted To - CodesOnBytes**
# ## **Project Link (GitHub) - [Click here](https://github.com/ajaythakur3369/COB/blob/main/Task_02.ipynb)**
# ## **Project Link (Drive) - [Click here](https://colab.research.google.com/drive/1Qi4l9ytTeMCvYIRg2SPgW59uQljsteR0)**

# %% [markdown]
# # **Problem Statement -**

# %% [markdown]
# Cleaned the Dataset, replaced Missing values, removed Outliers, etc.
#
# **Dataset -** https://docs.google.com/spreadsheets/d/e/2PACX-1vTSS-TcErkXNk8KB0AlijhitwetxeHD2M3R0HJl2QPMAyFq0fxFX4PFKnzAWLDnratIz67DNL6GsZnV/pub?output=csv

# %% [markdown]
# # **Let's Begin !**

# %%
# Import all required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Access the Drive from Colab, to access the file
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Folders/dataset_netflix1.csv")
df
# Out:
#      show_id     type                              title  \
# 0         s1    Movie               Dick Johnson Is Dead
# 1         s3  TV Show                          Ganglands
# 2         s6  TV Show                      Midnight Mass
# 3        s14    Movie   Confessions of an Invisible Girl
# 4         s9  TV Show      The Great British Baking Show
# ...      ...      ...                                ...
# 4772   s2543  TV Show               True: Terrific Tales
# 4773   s3351    Movie         True: Grabbleapple Harvest
# 4774   s3509    Movie             True: Tricky Treat Day
# 4775   s3554  TV Show       True and the Rainbow Kingdom
# 4776   s4241    Movie  Sam Kinison: The Scream Continues
#
#                           director         country  date_added  release_year  \
# 0                  Kirsten Johnson   United States   9/25/2021          2020
# 1                  Julien Leclercq          France   9/24/2021          2021
# 2                    Mike Flanagan   United States   9/24/2021          2021
# 3                    Bruno Garotti          Brazil   9/22/2021          2021
# 4                  Andy Devonshire  United Kingdom   9/24/2021          2021
# ...                            ...             ...         ...           ...
# 4772  Mark Thornton, Todd Kauffman          Canada   5/12/2020          2020
# 4773  Mark Thornton, Todd Kauffman          Canada   11/1/2019          2019
# 4774  Mark Thornton, Todd Kauffman          Canada   9/20/2019          2019
# 4775  Mark Thornton, Todd Kauffman   United States   8/30/2019          2019
# 4776              Walter C. Miller   United States  12/31/2018          2016
#
#      rating   duration                                          listed_in
# 0     PG-13     90 min                                      Documentaries
# 1     TV-MA   1 Season  Crime TV Shows, International TV Shows, TV Act...
# 2     TV-MA   1 Season                 TV Dramas, TV Horror, TV Mysteries
# 3     TV-PG     91 min                 Children & Family Movies, Comedies
# 4     TV-14  9 Seasons                       British TV Shows, Reality TV
# ...     ...        ...                                                ...
# 4772   TV-Y   1 Season                                           Kids' TV
# 4773   TV-Y     24 min                           Children & Family Movies
# 4774   TV-Y     24 min                           Children & Family Movies
# 4775   TV-Y  3 Seasons                                           Kids' TV
# 4776  TV-MA     29 min                                      Documentaries
#
# [4777 rows x 10 columns]

# %%
df.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s9  TV Show     The Great British Baking Show  Andy Devonshire
#
#           country date_added  release_year rating   duration  \
# 0   United States  9/25/2021          2020  PG-13     90 min
# 1          France  9/24/2021          2021  TV-MA   1 Season
# 2   United States  9/24/2021          2021  TV-MA   1 Season
# 3          Brazil  9/22/2021          2021  TV-PG     91 min
# 4  United Kingdom  9/24/2021          2021  TV-14  9 Seasons
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# 2                 TV Dramas, TV Horror, TV Mysteries
# 3                 Children & Family Movies, Comedies
# 4                       British TV Shows, Reality TV

# %%
df.shape
# Out:
# (4777, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4777 entries, 0 to 4776
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       4777 non-null   object
#  1   type          4777 non-null   object
#  2   title         4777 non-null   object
#  3   director      4777 non-null   object
#  4   country       4777 non-null   object
#  5   date_added    4777 non-null   object
#  6   release_year  4777 non-null   int64
#  7   rating        4777 non-null   object
#  8   duration      4777 non-null   object
#  9   listed_in     4777 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 373.3+ KB

# %%
df['director'] = df['director'].replace('Not Given', np.NaN)
df['country'] = df['country'].replace('Not Given', np.NaN)

# %%
df
# Out:
#      show_id     type                              title  \
# 0         s1    Movie               Dick Johnson Is Dead
# 1         s3  TV Show                          Ganglands
# 2         s6  TV Show                      Midnight Mass
# 3        s14    Movie   Confessions of an Invisible Girl
# 4         s9  TV Show      The Great British Baking Show
# ...      ...      ...                                ...
# 4772   s2543  TV Show               True: Terrific Tales
# 4773   s3351    Movie         True: Grabbleapple Harvest
# 4774   s3509    Movie             True: Tricky Treat Day
# 4775   s3554  TV Show       True and the Rainbow Kingdom
# 4776   s4241    Movie  Sam Kinison: The Scream Continues
#
#                           director         country  date_added  release_year  \
# 0                  Kirsten Johnson   United States   9/25/2021          2020
# 1                  Julien Leclercq          France   9/24/2021          2021
# 2                    Mike Flanagan   United States   9/24/2021          2021
# 3                    Bruno Garotti          Brazil   9/22/2021          2021
# 4                  Andy Devonshire  United Kingdom   9/24/2021          2021
# ...                            ...             ...         ...           ...
# 4772  Mark Thornton, Todd Kauffman          Canada   5/12/2020          2020
# 4773  Mark Thornton, Todd Kauffman          Canada   11/1/2019          2019
# 4774  Mark Thornton, Todd Kauffman          Canada   9/20/2019          2019
# 4775  Mark Thornton, Todd Kauffman   United States   8/30/2019          2019
# 4776              Walter C. Miller   United States  12/31/2018          2016
#
#      rating   duration                                          listed_in
# 0     PG-13     90 min                                      Documentaries
# 1     TV-MA   1 Season  Crime TV Shows, International TV Shows, TV Act...
# 2     TV-MA   1 Season                 TV Dramas, TV Horror, TV Mysteries
# 3     TV-PG     91 min                 Children & Family Movies, Comedies
# 4     TV-14  9 Seasons                       British TV Shows, Reality TV
# ...     ...        ...                                                ...
# 4772   TV-Y   1 Season                                           Kids' TV
# 4773   TV-Y     24 min                           Children & Family Movies
# 4774   TV-Y     24 min                           Children & Family Movies
# 4775   TV-Y  3 Seasons                                           Kids' TV
# 4776  TV-MA     29 min                                      Documentaries
#
# [4777 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df2 = df.dropna(axis = 0, how = 'any')

# %%
df2.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
print("After removing missing values",len(df2), "rows are present in the list.")
# Out:
# After removing missing values 4777 rows are present in the list.

# %%
df2
# Out:
#      show_id     type                              title  \
# 0         s1    Movie               Dick Johnson Is Dead
# 1         s3  TV Show                          Ganglands
# 2         s6  TV Show                      Midnight Mass
# 3        s14    Movie   Confessions of an Invisible Girl
# 4         s9  TV Show      The Great British Baking Show
# ...      ...      ...                                ...
# 4772   s2543  TV Show               True: Terrific Tales
# 4773   s3351    Movie         True: Grabbleapple Harvest
# 4774   s3509    Movie             True: Tricky Treat Day
# 4775   s3554  TV Show       True and the Rainbow Kingdom
# 4776   s4241    Movie  Sam Kinison: The Scream Continues
#
#                           director         country  date_added  release_year  \
# 0                  Kirsten Johnson   United States   9/25/2021          2020
# 1                  Julien Leclercq          France   9/24/2021          2021
# 2                    Mike Flanagan   United States   9/24/2021          2021
# 3                    Bruno Garotti          Brazil   9/22/2021          2021
# 4                  Andy Devonshire  United Kingdom   9/24/2021          2021
# ...                            ...             ...         ...           ...
# 4772  Mark Thornton, Todd Kauffman          Canada   5/12/2020          2020
# 4773  Mark Thornton, Todd Kauffman          Canada   11/1/2019          2019
# 4774  Mark Thornton, Todd Kauffman          Canada   9/20/2019          2019
# 4775  Mark Thornton, Todd Kauffman   United States   8/30/2019          2019
# 4776              Walter C. Miller   United States  12/31/2018          2016
#
#      rating   duration                                          listed_in
# 0     PG-13     90 min                                      Documentaries
# 1     TV-MA   1 Season  Crime TV Shows, International TV Shows, TV Act...
# 2     TV-MA   1 Season                 TV Dramas, TV Horror, TV Mysteries
# 3     TV-PG     91 min                 Children & Family Movies, Comedies
# 4     TV-14  9 Seasons                       British TV Shows, Reality TV
# ...     ...        ...                                                ...
# 4772   TV-Y   1 Season                                           Kids' TV
# 4773   TV-Y     24 min                           Children & Family Movies
# 4774   TV-Y     24 min                           Children & Family Movies
# 4775   TV-Y  3 Seasons                                           Kids' TV
# 4776  TV-MA     29 min                                      Documentaries
#
# [4777 rows x 10 columns]

# %%
df2.to_csv("/content/drive/MyDrive/Folders/dataset_netflix1.csv", index = False)

# %%
sns.boxplot(x = df2['release_year'])
plt.show()

# %%
sns.histplot(x = df2['release_year'], kde = True)
plt.show()

# %%
df2.describe()
# Out:
#        release_year
# count   4777.000000
# mean    2016.673645
# std        2.729047
# min     2010.000000
# 25%     2015.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
upper_limit=2018+1.5*6
lower_limit=2012-1.5*6

# %%
upper_limit
# Out:
# 2027.0

# %%
lower_limit
# Out:
# 2003.0

# %%
new_data = df2.loc[(df2['release_year']<upper_limit) & (df2['release_year']>lower_limit)]

# %%
new_data['release_year'].median()
# Out:
# 2017.0

# %%
sns.boxplot(x = new_data['release_year'])
plt.show()

# %%
sns.histplot(x = new_data['release_year'], kde = True)
plt.show()

# %%
lower_limit = 2016-1.5*6
lower_limit
# Out:
# 2007.0

# %%
new_data_1=new_data.loc[(new_data['release_year']<upper_limit) & (new_data['release_year']>lower_limit)]

# %%
sns.boxplot(x = new_data_1['release_year'])
plt.show()

# %%
sns.histplot(x = new_data_1['release_year'], kde = True)
plt.show()

# %%
lower_limit = 2018-1.5*6
lower_limit
# Out:
# 2009.0

# %%
new_data_2 = new_data_1.loc[(new_data_1['release_year']<upper_limit) & (new_data_1['release_year']>lower_limit)]

# %%
sns.boxplot(x = new_data_2['release_year'])
plt.show()

# %%
sns.histplot(x = new_data_2['release_year'], kde = True)
plt.show()

# %%
print("After removing outliers", len(new_data_2), "rows are present in the Dataset")
# Out:
# After removing outliers 4777 rows are present in the Dataset

# %%
new_data_2
# Out:
#      show_id     type                              title  \
# 0         s1    Movie               Dick Johnson Is Dead
# 1         s3  TV Show                          Ganglands
# 2         s6  TV Show                      Midnight Mass
# 3        s14    Movie   Confessions of an Invisible Girl
# 4         s9  TV Show      The Great British Baking Show
# ...      ...      ...                                ...
# 4772   s2543  TV Show               True: Terrific Tales
# 4773   s3351    Movie         True: Grabbleapple Harvest
# 4774   s3509    Movie             True: Tricky Treat Day
# 4775   s3554  TV Show       True and the Rainbow Kingdom
# 4776   s4241    Movie  Sam Kinison: The Scream Continues
#
#                           director         country  date_added  release_year  \
# 0                  Kirsten Johnson   United States   9/25/2021          2020
# 1                  Julien Leclercq          France   9/24/2021          2021
# 2                    Mike Flanagan   United States   9/24/2021          2021
# 3                    Bruno Garotti          Brazil   9/22/2021          2021
# 4                  Andy Devonshire  United Kingdom   9/24/2021          2021
# ...                            ...             ...         ...           ...
# 4772  Mark Thornton, Todd Kauffman          Canada   5/12/2020          2020
# 4773  Mark Thornton, Todd Kauffman          Canada   11/1/2019          2019
# 4774  Mark Thornton, Todd Kauffman          Canada   9/20/2019          2019
# 4775  Mark Thornton, Todd Kauffman   United States   8/30/2019          2019
# 4776              Walter C. Miller   United States  12/31/2018          2016
#
#      rating   duration                                          listed_in
# 0     PG-13     90 min                                      Documentaries
# 1     TV-MA   1 Season  Crime TV Shows, International TV Shows, TV Act...
# 2     TV-MA   1 Season                 TV Dramas, TV Horror, TV Mysteries
# 3     TV-PG     91 min                 Children & Family Movies, Comedies
# 4     TV-14  9 Seasons                       British TV Shows, Reality TV
# ...     ...        ...                                                ...
# 4772   TV-Y   1 Season                                           Kids' TV
# 4773   TV-Y     24 min                           Children & Family Movies
# 4774   TV-Y     24 min                           Children & Family Movies
# 4775   TV-Y  3 Seasons                                           Kids' TV
# 4776  TV-MA     29 min                                      Documentaries
#
# [4777 rows x 10 columns]

# %%
new_data_3 = new_data_2.to_csv("/content/drive/MyDrive/Folders/dataset_netflix1.csv", index = False)
print(new_data_3)
# Out:
# None
